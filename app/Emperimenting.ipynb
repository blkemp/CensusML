# %%
# Import statements
# Declare Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import make_scorer, r2_score, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
import os
import pickle
from textwrap import wrap
import operator
import au_census_analysis_functions as cnss_func

# Set a variable for current notebook's path for various loading/saving mechanisms
nb_path = os.getcwd()
td_path = os.path.dirname(os.path.realpath(nb_path))

# %%
import table_funcs as tbl_func

# %%
import importlib
importlib.reload(cnss_func)
# Out:
# <module 'au_census_analysis_functions' from 'C:\\Users\\kempbri\\OneDrive - Mars Inc\\Documents\\GitHub\\Census-ASGS-Level-and-Model-Sensitivity\\au_census_analysis_functions.py'>

# %% [markdown]
# ### Custom Functions
# Below creates a number of custom functions. These are also replicated in the au_census_analysis_functions.py file but for the time being I am leaving them here if I need to re-run some of the cells executed prior to the implementation of these as imported functions.

# %%
# Show tables which have the above fields of information available
df_meta = pd.read_csv('{}\Data\Metadata\Metadata_2016_refined.csv'.format(td_path))
df_m_refined = df_meta[(df_meta['Age'] > 0) |
                      (df_meta['Income'] > 0) |
                      (df_meta['Occupation'] > 0) |
                      (df_meta['Family Composition'] > 0) |
                      (df_meta['Internet status'] > 0) |
                      (df_meta['Building occupation status'] > 0) |
                      (df_meta['Number of Bedrooms'] > 0) |
                      (df_meta['Place of Birth'] > 0) |
                      (df_meta['Country of Birth of Parents'] > 0) |
                      (df_meta['Year of Arrival'] > 0)]
tables_to_load = df_m_refined['Profile table'].unique().tolist()
load_features = ['Age','Income']

# %% [markdown]
# ## Begin importing and exploring data

# %%
options_df = df_m_refined[['DataPack file','Table name']]
options_df = options_df.drop_duplicates(subset='DataPack file')
options_df = options_df.set_index('DataPack file')
options_df.head()
# Out:
#                                                     Table name
# DataPack file
# G01                     Selected Person Characteristics by Sex
# G03            Place of Usual Residence on Census Night by Age
# G04A                                                Age by Sex
# G04B                                                Age by Sex
# G05                    Registered Marital Status by Age by Sex

# %%
temp_df = pd.DataFrame(options_df['Table name'].value_counts()).reset_index()
temp_df.columns = ['Table name','Count']
options_df = options_df.reset_index().merge(temp_df, on='Table name')

# %%
options_df.loc[options_df.Count > 1, 'DataPack file'] = options_df['DataPack file'].str[:3]
options_df.drop_duplicates()
# Out:
#    DataPack file                                         Table name  Count
# 0            G01             Selected Person Characteristics by Sex      1
# 1            G03    Place of Usual Residence on Census Night by Age      1
# 2            G04                                         Age by Sex      2
# 4            G05            Registered Marital Status by Age by Sex      1
# 5            G06                Social Marital Status by Age by Sex      1
# 6            G07                   Indigenous Status by Age by Sex       1
# 7            G09           Country of Birth of Person by Age by Sex      8
# 15           G10  Country of Birth of Person by Year of Arrival ...      3
# 18           G11  Proficiency in Spoken English/Language by Year...      4
# 22           G12  Proficiency in Spoken English/Language of Pare...      2
# 24           G15  Type of Educational Institution Attending (Ful...      1
# 25           G16     Highest Year of School Completed by Age by Sex      2
# 27           G17       Total Personal Income (Weekly) by Age by Sex      3
# 30           G18    Core Activity Need for Assistance by Age by Sex      1
# 31           G19  Voluntary Work for an Organisation or Group by...      1
# 32           G20  Unpaid Domestic Work:  Number of House by Age ...      2
# 34           G21  Unpaid Assistance to a Person with a Disabilit...      1
# 35           G22                    Unpaid Child Care by Age by Sex      2
# 37           G23            Relationship in Household by Age by Sex      2
# 39           G24      Number of Children Ever Born by Age of Parent      1
# 40           G25                                 Family Composition      1
# 41           G26  Family Composition and Country of Birth of Par...      1
# 42           G27                                    Family Blending      1
# 43           G28  Total Family Income (Weekly) by Family Composi...      1
# 44           G29  Total Household Income (Weekly) by Household C...      1
# 45           G32                                 Dwelling Structure      1
# 46           G33  Tenure Type and Landlord Type by Dwelling Stru...      1
# 47           G34  Mortgage Repayment (Monthly) by Dwelling Struc...      1
# 48           G35  Mortgage Repayment (Monthly) by Family Composi...      1
# 49           G37  Dwelling Internet Connection by Dwelling Struc...      1
# 50           G38           Dwelling Structure by Number of Bedrooms      1
# 51           G39  Dwelling Structure by Household Composition an...      1
# 52           G40  Selected Labour Force, Education and Migration...      1
# 53           G43                  Labour Force Status by Age by Sex      2
# 55           G44  Labour Force Status by Sex of Parents by Age o...      6
# 61           G45  Labour Force Status by Sex of Parents by Age o...      2
# 63           G46  Non-School Qualification:  Level of Education ...      2
# 65           G47  Non-School Qualification:  Field of Study by A...      3
# 68           G48  Non-School Qualification:  Field of Study by O...      3
# 71           G49  Non-School Qualification:  Level of Education ...      3
# 74           G51               Industry of Employment by Age by Sex      4
# 78           G53               Industry of Employment by Occupation      2
# 80           G54  Total Family Income (Weekly) by Labour Force S...      2
# 82           G55  Total Family Income (Weekly) by Labour Force S...      2
# 84           G56  Total Family Income (Weekly) by Labour Force S...      2
# 86           G57                           Occupation by Age by Sex      2
# 88           G58                  Occupation by Hours Worked by Sex      2

# %%
options_dict = [{'label': index, 'value': val} for index, val in options_df['Table name'].iteritems()]

options_dict
# Out:
# [{'label': 'G01', 'value': 'Selected Person Characteristics by Sex'},
#  {'label': 'G03', 'value': 'Place of Usual Residence on Census Night by Age'},
#  {'label': 'G04A', 'value': 'Age by Sex'},
#  {'label': 'G04B', 'value': 'Age by Sex'},
#  {'label': 'G05', 'value': 'Registered Marital Status by Age by Sex'},
#  {'label': 'G06', 'value': 'Social Marital Status by Age by Sex'},
#  {'label': 'G07', 'value': 'Indigenous Status by Age by Sex '},
#  {'label': 'G09A', 'value': 'Country of Birth of Person by Age by Sex'},
#  {'label': 'G09B', 'value': 'Country of Birth of Person by Age by Sex'},
#  {'label': 'G09C', 'value': 'Country of Birth of Person by Age by Sex'},
#  {'label': 'G09D', 'value': 'Country of Birth of Person by Age by Sex'},
#  {'label': 'G09E', 'value': 'Country of Birth of Person by Age by Sex'},
#  {'label': 'G09F', 'value': 'Country of Birth of Person by Age by Sex'},
#  {'label': 'G09G', 'value': 'Country of Birth of Person by Age by Sex'},
#  {'label': 'G09H', 'value': 'Country of Birth of Person by Age by Sex'},
#  {'label': 'G10A',
#   'value': 'Country of Birth of Person by Year of Arrival in Australia'},
#  {'label': 'G10B',
#   'value': 'Country of Birth of Person by Year of Arrival in Australia'},
#  {'label': 'G10C',
#   'value': 'Country of Birth of Person by Year of Arrival in Australia'},
#  {'label': 'G11A',
#   'value': 'Proficiency in Spoken English/Language by Year of Arrival in Australia by Age'},
#  {'label': 'G11B',
#   'value': 'Proficiency in Spoken English/Language by Year of Arrival in Australia by Age'},
#  {'label': 'G11C',
#   'value': 'Proficiency in Spoken English/Language by Year of Arrival in Australia by Age'},
#  {'label': 'G11D',
#   'value': 'Proficiency in Spoken English/Language by Year of Arrival in Australia by Age'},
#  {'label': 'G12A',
#   'value': 'Proficiency in Spoken English/Language of Parents by Age of Dependent Children'},
#  {'label': 'G12B',
#   'value': 'Proficiency in Spoken English/Language of Parents by Age of Dependent Children'},
#  {'label': 'G15',
#   'value': 'Type of Educational Institution Attending (Full/Part-Time Student Status by Age) by Sex'},
#  {'label': 'G16A', 'value': 'Highest Year of School Completed by Age by Sex'},
#  {'label': 'G16B', 'value': 'Highest Year of School Completed by Age by Sex'},
#  {'label': 'G17A', 'value': 'Total Personal Income (Weekly) by Age by Sex'},
#  {'label': 'G17B', 'value': 'Total Personal Income (Weekly) by Age by Sex'},
#  {'label': 'G17C', 'value': 'Total Personal Income (Weekly) by Age by Sex'},
#  {'label': 'G18', 'value': 'Core Activity Need for Assistance by Age by Sex'},
#  {'label': 'G19',
#   'value': 'Voluntary Work for an Organisation or Group by Age by Sex '},
#  {'label': 'G20A',
#   'value': 'Unpaid Domestic Work:  Number of House by Age by Sex '},
#  {'label': 'G20B',
#   'value': 'Unpaid Domestic Work:  Number of House by Age by Sex '},
#  {'label': 'G21',
#   'value': 'Unpaid Assistance to a Person with a Disability by Age by Sex'},
#  {'label': 'G22A', 'value': 'Unpaid Child Care by Age by Sex'},
#  {'label': 'G22B', 'value': 'Unpaid Child Care by Age by Sex'},
#  {'label': 'G23A', 'value': 'Relationship in Household by Age by Sex'},
#  {'label': 'G23B', 'value': 'Relationship in Household by Age by Sex'},
#  {'label': 'G24', 'value': 'Number of Children Ever Born by Age of Parent'},
#  {'label': 'G25', 'value': 'Family Composition'},
#  {'label': 'G26',
#   'value': 'Family Composition and Country of Birth of Parents by Age of Dependent Children'},
#  {'label': 'G27', 'value': 'Family Blending'},
#  {'label': 'G28',
#   'value': 'Total Family Income (Weekly) by Family Composition'},
#  {'label': 'G29',
#   'value': 'Total Household Income (Weekly) by Household Composition'},
#  {'label': 'G32', 'value': 'Dwelling Structure'},
#  {'label': 'G33',
#   'value': 'Tenure Type and Landlord Type by Dwelling Structure'},
#  {'label': 'G34',
#   'value': 'Mortgage Repayment (Monthly) by Dwelling Structure'},
#  {'label': 'G35',
#   'value': 'Mortgage Repayment (Monthly) by Family Composition'},
#  {'label': 'G37',
#   'value': 'Dwelling Internet Connection by Dwelling Structure'},
#  {'label': 'G38', 'value': 'Dwelling Structure by Number of Bedrooms'},
#  {'label': 'G39',
#   'value': 'Dwelling Structure by Household Composition and Family Composition'},
#  {'label': 'G40',
#   'value': 'Selected Labour Force, Education and Migration Characteristics by Sex'},
#  {'label': 'G43A', 'value': 'Labour Force Status by Age by Sex'},
#  {'label': 'G43B', 'value': 'Labour Force Status by Age by Sex'},
#  {'label': 'G44A',
#   'value': 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'},
#  {'label': 'G44B',
#   'value': 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'},
#  {'label': 'G44C',
#   'value': 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'},
#  {'label': 'G44D',
#   'value': 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'},
#  {'label': 'G44E',
#   'value': 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'},
#  {'label': 'G44F',
#   'value': 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'},
#  {'label': 'G45A',
#   'value': 'Labour Force Status by Sex of Parents by Age of Dependent Children for Couple Families'},
#  {'label': 'G45B',
#   'value': 'Labour Force Status by Sex of Parents by Age of Dependent Children for Couple Families'},
#  {'label': 'G46A',
#   'value': 'Non-School Qualification:  Level of Education by Age by Sex'},
#  {'label': 'G46B',
#   'value': 'Non-School Qualification:  Level of Education by Age by Sex'},
#  {'label': 'G47A',
#   'value': 'Non-School Qualification:  Field of Study by Age by Sex'},
#  {'label': 'G47B',
#   'value': 'Non-School Qualification:  Field of Study by Age by Sex'},
#  {'label': 'G47C',
#   'value': 'Non-School Qualification:  Field of Study by Age by Sex'},
#  {'label': 'G48A',
#   'value': 'Non-School Qualification:  Field of Study by Occupation by Sex'},
#  {'label': 'G48B',
#   'value': 'Non-School Qualification:  Field of Study by Occupation by Sex'},
#  {'label': 'G48C',
#   'value': 'Non-School Qualification:  Field of Study by Occupation by Sex'},
#  {'label': 'G49A',
#   'value': 'Non-School Qualification:  Level of Education by Occupation  by Sex'},
#  {'label': 'G49B',
#   'value': 'Non-School Qualification:  Level of Education by Occupation  by Sex'},
#  {'label': 'G49C',
#   'value': 'Non-School Qualification:  Level of Education by Occupation  by Sex'},
#  {'label': 'G51A', 'value': 'Industry of Employment by Age by Sex'},
#  {'label': 'G51B', 'value': 'Industry of Employment by Age by Sex'},
#  {'label': 'G51C', 'value': 'Industry of Employment by Age by Sex'},
#  {'label': 'G51D', 'value': 'Industry of Employment by Age by Sex'},
#  {'label': 'G53A', 'value': 'Industry of Employment by Occupation'},
#  {'label': 'G53B', 'value': 'Industry of Employment by Occupation'},
#  {'label': 'G54A',
#   'value': 'Total Family Income (Weekly) by Labour Force Status of Partners for Couple Families with No Children'},
#  {'label': 'G54B',
#   'value': 'Total Family Income (Weekly) by Labour Force Status of Partners for Couple Families with No Children'},
#  {'label': 'G55A',
#   'value': 'Total Family Income (Weekly) by Labour Force Status of Parents/Partners for Couple Families with Children'},
#  {'label': 'G55B',
#   'value': 'Total Family Income (Weekly) by Labour Force Status of Parents/Partners for Couple Families with Children'},
#  {'label': 'G56A',
#   'value': 'Total Family Income (Weekly) by Labour Force Status of Parent for One Parent Families'},
#  {'label': 'G56B',
#   'value': 'Total Family Income (Weekly) by Labour Force Status of Parent for One Parent Families'},
#  {'label': 'G57A', 'value': 'Occupation by Age by Sex'},
#  {'label': 'G57B', 'value': 'Occupation by Age by Sex'},
#  {'label': 'G58A', 'value': 'Occupation by Hours Worked by Sex'},
#  {'label': 'G58B', 'value': 'Occupation by Hours Worked by Sex'}]

# %%
print ([x for x in options_df['Table name'].iteritems()])
# Out:
# [('G01', 'Selected Person Characteristics by Sex'), ('G03', 'Place of Usual Residence on Census Night by Age'), ('G04A', 'Age by Sex'), ('G04B', 'Age by Sex'), ('G05', 'Registered Marital Status by Age by Sex'), ('G06', 'Social Marital Status by Age by Sex'), ('G07', 'Indigenous Status by Age by Sex '), ('G09A', 'Country of Birth of Person by Age by Sex'), ('G09B', 'Country of Birth of Person by Age by Sex'), ('G09C', 'Country of Birth of Person by Age by Sex'), ('G09D', 'Country of Birth of Person by Age by Sex'), ('G09E', 'Country of Birth of Person by Age by Sex'), ('G09F', 'Country of Birth of Person by Age by Sex'), ('G09G', 'Country of Birth of Person by Age by Sex'), ('G09H', 'Country of Birth of Person by Age by Sex'), ('G10A', 'Country of Birth of Person by Year of Arrival in Australia'), ('G10B', 'Country of Birth of Person by Year of Arrival in Australia'), ('G10C', 'Country of Birth of Person by Year of Arrival in Australia'), ('G11A', 'Proficiency in Spoken English/Language by Year of Arrival in Australia by Age'), ('G11B', 'Proficiency in Spoken English/Language by Year of Arrival in Australia by Age'), ('G11C', 'Proficiency in Spoken English/Language by Year of Arrival in Australia by Age'), ('G11D', 'Proficiency in Spoken English/Language by Year of Arrival in Australia by Age'), ('G12A', 'Proficiency in Spoken English/Language of Parents by Age of Dependent Children'), ('G12B', 'Proficiency in Spoken English/Language of Parents by Age of Dependent Children'), ('G15', 'Type of Educational Institution Attending (Full/Part-Time Student Status by Age) by Sex'), ('G16A', 'Highest Year of School Completed by Age by Sex'), ('G16B', 'Highest Year of School Completed by Age by Sex'), ('G17A', 'Total Personal Income (Weekly) by Age by Sex'), ('G17B', 'Total Personal Income (Weekly) by Age by Sex'), ('G17C', 'Total Personal Income (Weekly) by Age by Sex'), ('G18', 'Core Activity Need for Assistance by Age by Sex'), ('G19', 'Voluntary Work for an Organisation or Group by Age by Sex '), ('G20A', 'Unpaid Domestic Work:  Number of House by Age by Sex '), ('G20B', 'Unpaid Domestic Work:  Number of House by Age by Sex '), ('G21', 'Unpaid Assistance to a Person with a Disability by Age by Sex'), ('G22A', 'Unpaid Child Care by Age by Sex'), ('G22B', 'Unpaid Child Care by Age by Sex'), ('G23A', 'Relationship in Household by Age by Sex'), ('G23B', 'Relationship in Household by Age by Sex'), ('G24', 'Number of Children Ever Born by Age of Parent'), ('G25', 'Family Composition'), ('G26', 'Family Composition and Country of Birth of Parents by Age of Dependent Children'), ('G27', 'Family Blending'), ('G28', 'Total Family Income (Weekly) by Family Composition'), ('G29', 'Total Household Income (Weekly) by Household Composition'), ('G32', 'Dwelling Structure'), ('G33', 'Tenure Type and Landlord Type by Dwelling Structure'), ('G34', 'Mortgage Repayment (Monthly) by Dwelling Structure'), ('G35', 'Mortgage Repayment (Monthly) by Family Composition'), ('G37', 'Dwelling Internet Connection by Dwelling Structure'), ('G38', 'Dwelling Structure by Number of Bedrooms'), ('G39', 'Dwelling Structure by Household Composition and Family Composition'), ('G40', 'Selected Labour Force, Education and Migration Characteristics by Sex'), ('G43A', 'Labour Force Status by Age by Sex'), ('G43B', 'Labour Force Status by Age by Sex'), ('G44A', 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'), ('G44B', 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'), ('G44C', 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'), ('G44D', 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'), ('G44E', 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'), ('G44F', 'Labour Force Status by Sex of Parents by Age of Dependent Children for One Parent Families'), ('G45A', 'Lab ...
